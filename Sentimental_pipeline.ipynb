# %% [markdown]
# <a href="https://colab.research.google.com/github/nishank1225/ML-practice/blob/main/Sentimental_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
from transformers import pipeline
sentiment_pipline=pipeline("sentiment-analysis")
sentences=["I love this phone the battery life is amazing"]

result=sentiment_pipline(sentences)
for sentence, result in zip(sentences, result):
  print(f"Sentence:" ,sentence)
  print(f"Sentiment:", result['label'])
  print("Score: ",result['score'])
# Out:
# ...
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# Sentence: I love this phone the battery life is amazing
# Sentiment: POSITIVE
# Score:  0.9998680353164673
